# %%
#insertion in set
s={"hello","hi","Sai"}
print(s)
len(s)
# Out:
# {'Sai', 'hi', 'hello'}
# 3

# %%
#insertion in set
s={"hello","hi","FALSE","Sai","TRUE"}
print(s)
# Out:
# {'TRUE', 'FALSE', 'Sai', 'hi', 'hello'}

# %%
a=[4,5,6,7,8,9]
sort(a)
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-70cf0a7984a8> in <cell line: 2>()
#       1 a=[4,5,6,7,8,9]
# ----> 2 sort(a)
#       3 print(a)
#
# NameError: name 'sort' is not defined

# %%
#sorted fun in list
a=[4,15,6,7,28,9]
b=sorted(a)
print(b)
# Out:
# [4, 6, 7, 9, 15, 28]

# %%
set={"apple","hii","chinni"}
for i in set:
  print(i)
# Out:
# chinni
# hii
# apple

# %%
set={"apple","hii","chinni"}
set.add("cherry")
print(set)
# Out:
# {'chinni', 'cherry', 'hii', 'apple'}

# %%
set={"apple","hii","chinni"}
set.remove("hii")
print(set)
# Out:
# {'chinni', 'apple'}

# %%
s={"apple","hii","chinni"}
print(len(s))
# Out:
# 3

# %%
t=("apple","hii","chinni")
print(t)
# Out:
# ('apple', 'hii', 'chinni')

# %%
t=("apple","hii","chinni")
print(len(t))
# Out:
# 3

# %%
t=("apple","hii","chinni")
tuple=("eye","ear")
print(t+tuple)
# Out:
# ('apple', 'hii', 'chinni', 'eye', 'ear')

# %%
t=("apple","hii","chinni")
print(t[1])
# Out:
# hii

# %%
t=("apple","hii","chinni","everyone")
for i in t:
  print(i)
# Out:
# apple
# hii
# chinni
# everyone
