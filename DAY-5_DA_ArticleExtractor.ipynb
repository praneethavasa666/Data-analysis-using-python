# %%
import requests

url = "https://article-extractor-and-summarizer.p.rapidapi.com/summarize"

querystring = {"url":"https://time.com/6266679/musk-ai-open-letter/","length":"3"}

headers = {
	"X-RapidAPI-Key": "a14dd82b19msh41eb4646334b19fp1d6b85jsnef371dc5c27e",
	"X-RapidAPI-Host": "article-extractor-and-summarizer.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'summary': 'The open letter signed by hundreds of tech leaders, including Elon Musk, calls for a six-month pause in the training of new super-powerful AI systems due to the risks they pose to society and humanity. This comes after the release of OpenAI\'s GPT-4, the most powerful AI system ever released, which has led to concerns about humanity\'s future as an AI arms race intensifies. The letter emphasizes the need for planning and management of advanced AI with care and resources, as the current race to develop powerful digital minds is out of control.\n\nThe signatories of the letter, which includes over 1,000 names, raise questions about the impact of AI on society, such as the spread of propaganda, automation of jobs, and the potential for nonhuman minds to outsmart and replace humans. The letter urges AI labs to use the proposed six-month pause to focus on safety research and develop shared safety protocols for advanced AI design and development. The signatories stress the importance of slowing down the development of AI systems to allow society to adapt and ensure the safety and verifiability of these systems.\n\nThe letter concludes with a hopeful message that society has the ability to pause the development of potentially catastrophic technologies, emphasizing the need to enjoy a "long AI summer" rather than rushing into unforeseen consequences. Signatories like Gary Marcus and Simeon Campos highlight the responsibility of tech leaders and the importance of addressing the risks associated with AI systems, calling for a more thoughtful approach to their development.'}
