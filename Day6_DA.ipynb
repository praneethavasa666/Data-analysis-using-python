# %%
from bs4 import BeautifulSoup as bs

# %%
import requests

url = "https://article-extractor-and-summarizer.p.rapidapi.com/summarize"

querystring = {"url":"https://www.geeksforgeeks.org/dbms/","length":"3"}

headers = {
	"X-RapidAPI-Key": "941bf60721mshf9157d67d16ba37p134c0fjsn90d1bad5304c",
	"X-RapidAPI-Host": "article-extractor-and-summarizer.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'summary': 'The text provides a comprehensive overview of various topics related to database management systems (DBMS), including indexing, file organization, advanced topics, SQL tutorials, DBMS practice questions, advantages of DBMS, and FAQs on DBMS. The indexing section covers different types of indexing such as B-Tree, B+ Tree, Bitmap Indexing, Inverted Index, and SQL queries on clustered and non-clustered indexes. File organization topics include hashing in DBMS and various file organization techniques. Advanced topics cover RAID, query optimization, password storage, storage area networks, data warehousing, data mining, ODBMS, HBase, Hive, database security challenges, and distributed database systems.\n\nThe advantages of learning DBMS are highlighted, such as organizing and managing data efficiently, ensuring data security, improving decision-making through data analysis, and maintaining consistency in database operations. The FAQs section addresses common questions about databases, including definitions, different languages used in DBMS (DDL, DML, DCL, TCL), ACID properties (Atomicity, Consistency, Isolation, Durability), and the advantages of DBMS, such as data sharing, integrity, data independence, and data security. The text also provides quick links to access more detailed information on each topic.\n\nOverall, the text serves as a valuable resource for individuals looking to enhance their knowledge of database management systems, covering a wide range of topics from basic concepts to advanced techniques and best practices in DBMS. It offers a structured approach to learning about indexing, file organization, SQL tutorials, and advanced topics in the field, providing a solid foundation for understanding and working with databases effectively. Additionally, the FAQs section addresses common queries and clarifies key concepts related to databases, making it a useful reference for both beginners and experienced professionals in the field of database management.'}

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
model1 = RandomForestClassifier(n_estimators=10)

# %%
df = pd.read_csv("/content/demodt.txt")
df
# Out:
#    State  Literacy  Cleanliness  Crime_Rate  Good
# 0      A        92           90          54     0
# 1      B        56           67          50     1
# 2      C        78           85          62     0
# 3      D        63           72          48     1
# 4      E        85           79          55     0
# 5      F        71           68          58     0
# 6      G        80           83          51     0
# 7      H        67           74          47     1
# 8      I        89           88          53     0
# 9      J        58           65          49     1
# 10     K        82           81          60     0
# 11     L        75           78          57     0
# 12     M        69           70          46     1
# 13     N        87           86          52     0
# 14     O        61           63          45     1
# 15     P        93           91          56     0
# 16     Q        55           66          61     0
# 17     R        76           77          59     0
# 18     S        84           82          44     1
# 19     T        70           69          50     1
# 20     U        94           92          57     0
# 21     V        59           64          52     0
# 22     W        83           80          43     1
# 23     X        74           76          63     0
# 24     Y        68           73          41     1
# 25     Z        88           84          47     1

# %%
features_col = ['Literacy','Cleanliness','Crime_Rate']
feature= df[features_col]
Target=df.Good

# %%
model1.fit(feature,Target)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
model1.fit(feature,Target)

model1.predict([[32,45,78]])

#Saving all Decision Tress
import os
output_dir = "tree_visualizations"
os.makedirs(output_dir,exist_ok= True)

for i, tree in enumerate(model1.estimators_):
  tree_dot_file = os.path.join(output_dir, f"tree_{i}.dot")
  tree_png_file = os.path.join(output_dir, f"tree_{i}.png")

model1.estimators_

for i, tree in enumerate(model1.estimators_):
  tree_dot_file = os.path.join(output_dir, f"tree_{i}.dot")
  tree_png_file = os.path.join(output_dir, f"tree_{i}.png")

from sklearn.tree import export_graphviz
export_graphviz(tree, out_file=tree_dot_file, feature_names=["Literacy", "Cleanliness", "Crime_Rate"],
                    class_names=[str(cls) for cls in model1.classes_], filled=True, rounded=True)

command = f"dot -Tpng {tree_dot_file} -o {tree_png_file}"
os.system(command)
print(f"Tree {i} visualization saved to {tree_png_file}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Tree 9 visualization saved to tree_visualizations/tree_9.png
