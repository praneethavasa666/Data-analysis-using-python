# %%
# !pip install requests
import requests as rs
import json
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)

# %%
import requests

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
    'start': '1',
    'limit': '5',  # Adjusted limit for demonstration purposes
    'convert': 'USD'
}
headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': '583439a8-8a61-42c5-b333-0639ad87200c',
}

try:
    response = requests.get(url, params=parameters, headers=headers)
    data = response.json()
    print(data)
except requests.RequestException as e:
    print(e)
# Out:
# {'status': {'timestamp': '2024-03-03T05:09:56.426Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 1247, 'name': 'bazhoao36bq', 'symbol': '7z1cv43wq3f', 'slug': 'fdwnv70loc5', 'cmc_rank': 9979, 'num_market_pairs': 6930, 'circulating_supply': 8218, 'total_supply': 7565, 'max_supply': 9075, 'infinite_supply': None, 'last_updated': '2024-03-03T05:09:56.426Z', 'date_added': '2024-03-03T05:09:56.426Z', 'tags': ['hzz0860jr37', '6zhixny6vw6', 'k3amm0mm5u', 'zbo1338jquk', '85j0pupel6h', 'i2f46tdpi18', 's0fgqywe5bl', 'd4newnb2nna', 'o30cyz5dgml', '2j7vbcaa92u'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.6508095412817965, 'volume_24h': 7774, 'volume_change_24h': 0.36251953119185276, 'percent_change_1h': 0.06442601033925022, 'percent_change_24h': 0.4275922932551697, 'percent_change_7d': 0.39797903267256607, 'market_cap': 0.05880439635539969, 'market_cap_dominance': 6295, 'fully_diluted_market_cap': 0.6809403898531388, 'last_updated': '2024-03-03T05:09:56.426Z'}}}, {'id': 826, 'name': '33i7sy1d2n4', 'symbol': 'vjz7valhut', 'slug': '1lngo2uf02a', 'cmc_rank': 5132, 'num_market_pairs': 9878, 'circulating_supply': 3420, 'total_supply': 9131, 'max_supply': 8473, 'infinite_supply': None, 'last_updated': '2024-03-03T05:09:56.426Z', 'date_added': '2024-03-03T05:09:56.426Z', 'tags': ['w0zniuiji7b', '0vfn72q5ryek', 'dbfy5tnzf6d', '65jrj8rr9g', 'gb4tu34tvy4', 'd511fza9vet', 'lr8otrrbxre', 'xlhjdglisyg', 'x8k7ke7z5', 'wd6iygi5j1'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.38505737896826386, 'volume_24h': 160, 'volume_change_24h': 0.4726475619237267, 'percent_change_1h': 0.9648322509958849, 'percent_change_24h': 0.680032268207571, 'percent_change_7d': 0.2279848319972031, 'market_cap': 0.6506821153907281, 'market_cap_dominance': 266, 'fully_diluted_market_cap': 0.9993566719538602, 'last_updated': '2024-03-03T05:09:56.426Z'}}}, {'id': 5066, 'name': 'ew771ttawzd', 'symbol': 'euj7n77zqqh', 'slug': 'tq753r5imk7', 'cmc_rank': 5723, 'num_market_pairs': 8702, 'circulating_supply': 9040, 'total_supply': 4979, 'max_supply': 4471, 'infinite_supply': None, 'last_updated': '2024-03-03T05:09:56.426Z', 'date_added': '2024-03-03T05:09:56.426Z', 'tags': ['apjblmqnib9', 'n47r6ymf66', 'momy5qdmbgs', 'y82lchzah5', 'fa4865y1v7h', '9b33kt8pg3t', 'e64aihxp0jk', 'lkxutpxgtc', '3y7mg8v9w6g', 'gkc1gt9dyd6'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.6746045078306036, 'volume_24h': 4261, 'volume_change_24h': 0.5769676352279058, 'percent_change_1h': 0.3290500243267751, 'percent_change_24h': 0.6119976468093751, 'percent_change_7d': 0.2601451324585795, 'market_cap': 0.08917424497360016, 'market_cap_dominance': 1408, 'fully_diluted_market_cap': 0.8970556702997332, 'last_updated': '2024-03-03T05:09:56.426Z'}}}, {'id': 3161, 'name': '2tc2m1c4jp5', 'symbol': '3qhe929ijd7', 'slug': 'u0qkimg65y', 'cmc_rank': 7743, 'num_market_pairs': 8988, 'circulating_supply': 95, 'total_supply': 1615, 'max_supply': 2933, 'infinite_supply': None, 'last_updated': '2024-03-03T05:09:56.426Z', 'date_added': '2024-03-03T05:09:56.426Z', 'tags': ['s8bqbpz9ksp', 'kut3ank3zv', 'r1xj590exyf', 'gc1tsn04sq5', 'cva3dl5bjle', 'p8cmvuunof', 'i1q5elb7v1', 'xitj7sn9aq', '5n2vi34l6hu', '2ivieitxuam'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.6015592366781601, 'volume_24h': 5, 'volume_change_24h': 0.20455177767364296, 'percent_change_1h': 0.638940166607876, 'percent_change_24h': 0.011738369614409994, 'percent_change_7d': 0.18571276175921492, 'market_cap': 0.19401933119070414, 'market_cap_dominance': 5731, 'fully_diluted_market_cap': 0.14101738064348623, 'last_updated': '2024-03-03T05:09:56.426Z'}}}, {'id': 3682, 'name': '65wi3y38628', 'symbol ...

# %%
api_key =" 583439a8-8a61-42c5-b333-0639ad87200c"
url = f"https://sandbox-api.coinmarketcap.com/v1/cryptocurrency.json?key={api_key}"
response = rs.get(url)
data = json.loads(response.text)
#data = response.json()
print(data)
# Out:
# {'statusCode': 404, 'error': 'Not Found', 'message': 'Not Found'}

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
import requests as rs
url = f"https://currencyconverter.p.rapidapi.com/availablecurrencies"
X_RapidAPI_Key == "941bf60721mshf9157d67d16ba37p134c0fjsn90d1bad5304c"
X_RapidAPI_Host == "currencyconverter.p.rapidapi.com"
response = rs.get(url)
data = response .json()
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b2fa30edae18> in <cell line: 3>()
#       1 import requests as rs
#       2 url = f"https://currencyconverter.p.rapidapi.com/availablecurrencies"
# ----> 3 X_RapidAPI_Key == "941bf60721mshf9157d67d16ba37p134c0fjsn90d1bad5304c"
#       4 X_RapidAPI_Host == "currencyconverter.p.rapidapi.com"
#       5 response = rs.get(url)
#
# NameError: name 'X_RapidAPI_Key' is not defined

# %%
import requests
url = "https://currencyconverter.p.rapidapi.com/availablecurrencies"

headers = {
	"X-RapidAPI-Key": "941bf60721mshf9157d67d16ba37p134c0fjsn90d1bad5304c",
	"X-RapidAPI-Host": "currencyconverter.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'messages': 'The API is unreachable, please contact the API provider', 'info': 'Your Client (working) ---> Gateway (working) ---> API (not working)'}

# %%
import requests

url = "https://article-extractor-and-summarizer.p.rapidapi.com/summarize"

querystring = {"url":"https://time.com/6266679/musk-ai-open-letter/","length":"3"}

headers = {
	"X-RapidAPI-Key": "941bf60721mshf9157d67d16ba37p134c0fjsn90d1bad5304c",
	"X-RapidAPI-Host": "article-extractor-and-summarizer.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'summary': "The text discusses an open letter signed by hundreds of prominent figures in the tech industry, including Elon Musk, calling for a six-month pause in the training of new super-powerful AI systems. This request comes in light of recent advances in AI, which are seen as posing significant risks to society and humanity. The release of OpenAI's GPT-4, the most powerful AI system to date, has led experts to reconsider their expectations regarding the arrival of artificial general intelligence (AGI) that surpasses human cognitive abilities. The fear is that an AI arms race could lead humanity into a catastrophic situation.\n\nThe letter emphasizes the need for planning and managing the development of advanced AI with great care and resources. It points out that the current race to develop increasingly powerful AI systems is happening without adequate planning or management, potentially leading to the creation of digital minds that are beyond human understanding or control. The signatories, which include over 1,000 individuals, highlight the importance of developing shared safety protocols for advanced AI design and development, overseen by independent experts. The goal is to ensure that AI systems adhere to safety standards that are rigorously audited.\n\nExperts who signed the letter express concerns about the risks posed by AI systems that are rapidly advancing without clear understanding or control. They stress the importance of slowing down the development of these systems to allow society to adapt and to accelerate the creation of safe and verifiable AGI architectures. The letter ends on a hopeful note, suggesting that society has the ability to pause and carefully consider the implications of AI technologies before rushing into potentially harmful outcomes."}

# %%
import requests

url = "https://article-extractor-and-summarizer.p.rapidapi.com/summarize"

querystring = {"url":"https://www.geeksforgeeks.org/dbms/","length":"3"}

headers = {
	"X-RapidAPI-Key": "941bf60721mshf9157d67d16ba37p134c0fjsn90d1bad5304c",
	"X-RapidAPI-Host": "article-extractor-and-summarizer.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'summary': 'The text discusses various aspects of database management systems (DBMS), including indexing, file organization, advanced topics, SQL tutorials, and practice questions. It covers topics such as B-Tree, B+ Tree, bitmap indexing, inverted index, SQL queries on clustered and non-clustered indexes, RAID, query optimization, data warehousing, data mining, distributed database systems, and more. The advantages of learning DBMS are highlighted, such as organizing and managing data, data security, improved decision-making, and consistency.\n\nThe text also includes frequently asked questions (FAQs) on DBMS, covering topics like the definition of a database, different languages present in DBMS (DDL, DML, DCL, TCL), the ACID properties in DBMS (Atomicity, Consistency, Isolation, Durability), and the advantages of DBMS, such as data sharing, integrity, data independence, and data security. The FAQs provide a comprehensive overview of key concepts and features of DBMS for readers to understand and apply in their database management practices.\n\nOverall, the text serves as a comprehensive guide to various aspects of DBMS, providing insights into different topics, tutorials, practice questions, and FAQs. It aims to help readers enhance their understanding of database management systems, improve their data management skills, and make informed decisions in utilizing DBMS for efficient data organization, security, and decision-making purposes. Additionally, quick links are provided for easy access to related resources and topics for further exploration and learning.'}
